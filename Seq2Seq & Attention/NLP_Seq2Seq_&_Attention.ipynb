# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random
import os
import io
import string
import re
from sklearn.model_selection import train_test_split

# %%
en_filename = "dataset/train.en.txt"
vi_filename = "dataset/train.vi.txt"

raw_en_lines = open(en_filename, encoding='utf-8').read().strip().split("\n")
raw_vi_lines = open(vi_filename, encoding='utf-8').read().strip().split("\n")

# %%
exclude = list(string.punctuation) + list(string.digits)

def preprocess(sentence):
    sent = sentence.lower()
    sent = sent.strip()
    sent = re.sub("'", " ", sent)
    sent = re.sub("\s+", " ", sent)
    sent = ''.join([char for char in sent if char not in exclude])
    sent = "<start> " + sent + " <end>"
    return sent

# %%
en_lines = []
vi_lines = []
min_len, max_len = 10, 14

for eline, vline in zip(raw_en_lines, raw_vi_lines):
    eline = preprocess(eline)
    vline = preprocess(vline)
    if min_len < len(eline.split(" ")) < max_len and min_len < len(vline.split(" ")) < max_len:
        en_lines.append(eline)
        vi_lines.append(vline)
        
print(len(en_lines))
# Out:
# 6016

# %%
class Language():
    def __init__(self, lines):
        self.lines = lines
        self.word2id = {}
        self.id2word = {}
        self.vocab = set()
        self.max_len = 0
        self.min_len = 0
        self.vocab_size = 0
        self.init_language_params()

    def init_language_params(self):
        for line in self.lines:
            self.vocab.update(line.split(" "))
        self.word2id['<pad>'] = 0
        for id, word in enumerate(self.vocab):
            self.word2id[word] = id + 1
        for word, id in self.word2id.items():
            self.id2word[id] = word
        self.max_len = max([len(line.split(" ")) for line in self.lines])
        self.min_len = min([len(line.split(" ")) for line in self.lines])
        self.vocab_size = len(self.vocab) + 1
            
    def sentence_to_vector(self, sent):
        return np.array([self.word2id[word] for word in sent.split(" ")])
            
    def vector_to_sentence(self, vector):
        return " ".join([self.id2word[id] for id in vector])

# %%
inp_lang = Language(en_lines)
tar_lang = Language(vi_lines)
print(inp_lang.max_len, inp_lang.min_len)
print(tar_lang.max_len, tar_lang.min_len)

inp_vector = [inp_lang.sentence_to_vector(line) for line in inp_lang.lines]
tar_vector = [tar_lang.sentence_to_vector(line) for line in tar_lang.lines]

inp_tensor = tf.keras.preprocessing.sequence.pad_sequences(inp_vector, inp_lang.max_len, padding='post')
tar_tensor = tf.keras.preprocessing.sequence.pad_sequences(tar_vector, tar_lang.max_len, padding='post')
print(inp_tensor.shape, tar_tensor.shape)
# Out:
# 13 11
# 13 11
# (6016, 13) (6016, 13)

# %%
i = 3
print(inp_tensor[i], type(inp_tensor[i]))
sent = inp_lang.vector_to_sentence(inp_tensor[i]) 
print(sent, type(sent))
vector = inp_lang.sentence_to_vector(inp_lang.vector_to_sentence(inp_tensor[i]))
print(vector, type(vector))
for inp, tar in zip(inp_tensor, tar_tensor):
    print(inp_lang.vector_to_sentence(inp))
    print(tar_lang.vector_to_sentence(tar))
# Out:
# Streaming output truncated to the last 5000 lines.
# <start> audience      and the month  <end> <pad>
# <start> khán giả      tháng  <end> <pad> <pad>
# <start> good  how about the person behind her  <end> <pad> <pad>
# <start> tốt  còn người ngồi phía sau cô  <end> <pad> <pad>
# <start> audience      and the month  <end> <pad>
# <start> khán giả      tháng  <end> <pad> <pad>
# <start> so  without any more stalling  here we go  <end>
# <start> vậy  không trì hoãn nữa bắt đầu thôi  <end> <pad>
# <start>  becomes cookie fission  cookie fission is   <end> <pad>
# <start>  trở thành cookie fission  cookie fission là   <end>
# <start> so here aposs gdp per person in america  <end> <pad> <pad>
# <start> đây chính là gdp của mỗi người ở mỹ  <end> <pad>
# <start> but you know  watson is growing up fast  <end> <pad>
# <start> nhưng các bạn biết watson đang phát triển nhanh chóng <end> <pad>
# <start> but all of these attempts have one thing in common  <end>
# <start> nhưng tất cả những nỗ lực ấy có một điểm chung <end>
# <start> quot oh  but surely someone must be in charge  <end>
# <start> quot oh  nhưng chắc phải có ai đó chứ  <end>
# <start> quot no  no  no one is in charge  <end>
# <start> quot không  không  không ai hết mà  <end> <pad>
# <start> this is a map of stockholm  my hometown  <end> <pad>
# <start> đây là bản đồ của stockholm  quê hương tôi  <end>
# <start> because you still have  percent of the traffic  <end> <pad>
# <start> bởi bạn vẫn còn   tham gia giao thông  <end>
# <start> and it turned out that they don apost know themselves  <end>
# <start> và kết quả là chính họ cũng không biết  <end> <pad>
# <start> they aposre not even aware of this themselves  <end> <pad> <pad>
# <start> chính họ cũng không tự nhận thức được điều đó  <end>
# <start> you should just nudge them in the right direction  <end> <pad>
# <start> bạn nên chỉ đẩy họ theo hướng đúng  <end> <pad> <pad>
# <start> but i really like my tea sweet  quot <end> <pad> <pad>
# <start> nhưng tôi thật sự thích trà ngọt  quot <end> <pad> <pad>
# <start> it aposs called quot being true to yourself  quot <end> <pad>
# <start> đó được gọi là quot là bản thân mình quot  <end>
# <start> we do not need everything that is there  quot <end> <pad>
# <start> chúng tôi không cần mọi thứ ở đây  quot <end> <pad>
# <start> how did they get me to do that  quot <end> <pad>
# <start> sao họ lại khiến tôi làm thế được  quot <end> <pad>
# <start> in a number of cases they were even clinically depressed  <end>
# <start> và trong nhiều trường hợp họ cảm thấy chán nản  <end>
# <start> and one was called quot ballet slippers  quot <end> <pad> <pad>
# <start> một cái gọi là quot giày ba lê quot <end> <pad> <pad>
# <start> and the other one was called quot adorable  quot <end> <pad>
# <start> cái khác gọi là quot đáng yêu quot  <end> <pad> <pad>
# <start> quot it aposs a glamorous shade of pink  quot <end> <pad>
# <start> quot nó là tông màu hồng duyên dáng quot <end> <pad> <pad>
# <start> thank you  sheena iyengar  thank you sheena  <end> <pad>
# <start> cảm ơn  sheena lyengar  cảm ơn sheena <end> <pad> <pad>
# <start> and i was like  quot sure  quot <end> <pad> <pad>
# <start> và tôi trả lời  quot đương nhiên rồi  quot <end>
# <start> and after a few months i was writing songs  <end> <pad>
# <start> và sau một vài tháng tôi viết nhạc  <end> <pad> <pad>
# <start> and i sat down  she sat on my lap  <end>
# <start> tôi ngồi xuống  cô bé ngồi vào lòng tôi <end> <pad>
# <start> and it came up with  different species of products  <end>
# <start> và có tới  cá thể khác nhau  <end> <pad> <pad>
# <start> and the answer is  all of them  <end> <pad> <pad>
# <start> và câu trả lời là  tất cả chúng  <end> <pad>
# <start> i don apost know who needs a corn sheller  <end> <pad>
# <start> tôi không biết ai cần một cái máy lột bắp  <end>
# <start> we aposve heard about the japanese giving up guns  <end> <pad>
# <start> chúng ta từng nghe về người nhật bỏ súng  <end> <pad>
# <start> that aposs the definition  there was no temperature  <end> <pad>
# <start> đó là định nghĩa  không có nhiệt độ  <end> <pad>
# <start> we want a trillion zillion species of one individuals  <end> <pad>
# <start> chúng ta muốn một trong vô kể sinh vật  <end> <pad>
# <start> they checked schedules  they were meeting with secretaries  <end> <pad>
# <start> kiểm tra lịch trình  họp với các thư ký  <end>
# <start> it aposs the first time we aposd done this  <end> <pad>
# <start> đó là lần đầu tiên chúng tôi làm điều này  <end>
# <start> didn apost read anything  quot there it is  quot <end>
# <start> mà không đọc gì cả  quot đây ạ  quot <end>
# <start> today it aposs less than  cents a day  <end> <pad>
# <start> ngày nay nó chỉ hơn  cent cho một ngày  <end>
# <start> it aposs going to look a little bit like that  <end>
# <start> nó sẽ trông một chút tương tự như thế này  <end>
# <start> it is abundance  as opposed to scarcity  <end> <pad> <pad>
# <start> nó phổ biến  trái ngược với sự khan hiếm  <end>
# <start> i aposm the younger one there  to the side  <end>
# <start> tôi trông trẻ hơn và đứng ngay bên cạnh  <end> <pad>
# <start> george  thank you for coming to ted  <end> <pad> <pad>
# <start> george  cảm ơn anh vì đã đến với ted  <end>
# <start> gp  thank you very much  thank you  <end> <pad>
# <start> cảm ơn các bạn rất nhiều  xin cảm ơn  <end>
# <start> so there has been a lot of change  <end> <pad> <pad>
# <start> vì vậy  đã có rất nhiều thay đổi  <end> <pad>
# <start> one hundred thousand posters have been printed this year  <end> <pad>
# <start>  tấm áp phích đã được in năm nay  <end> <pad>
# <start> they were all holding their photo as a statement  <end> <pad>
# <start> họ giữ hình ảnh của mình như một tuyên bố  <end>
# <start> and you know what  it aposs just the beginning  <end>
# <start> và bạn biết không  nó chỉ là sự khởi đầu <end>
# <start> let aposs turn the world inside out together  <end> <pad> <pad>
# <start> hãy biến thế giới từ trong ra ngoài cùng nhau  <end>
# <start> has been with me ever since i was a child  <end>
# <start> đã ám ảnh tôi từ khi còn nhỏ  <end> <pad> <pad>
# <start> but she told the students to sit down  <end> <pad> <pad>
# <start> nhưng bà đã bảo đám sinh viên ngồi xuống  <end> <pad>
# <start> and they aposre doing what they think is best  <end> <pad>
# <start> và làm những gì mà họ cho là tốt nhất  <end>
# <start> so that aposs the third one  anger  <end> <pad> <pad>
# <start> sự tức giận chính là cách thứ ba  <end> <pad> <pad>
# <start> so the training of the troops has to change  <end> <pad>
# <start> thế nên phải thay đổi việc huấn luyện quân đội  <end>
# <start> now that to me is wisdom in action  <end> <pad> <pad>
# <start> với tôi  đó là một hành động khôn ngoan  <end>
# <start> in the moment  that aposs what he did  <end> <pad>
# <start> cái cách mà ông ấy làm tại thời khắc đó  <end>
# <start> and it aposs been translated into  languages  <end> <pad> <pad>
# <start> cuốn sách đã được dịch ra  thứ tiếng <end> <pad> <pad>
# <start> zoom into it and see where it was taken  <end> <pad>
# <start> phóng to nó và nhìn thấy nơi nó được chụp  <end>
# <start> is this something that other people can do  <end> <pad> <pad>
# <start> có điều gì mà những người khác có thể làm  <end>
# <start> all right  mike  thanks so much  <end> <pad> <pad>
# <start> được rồi  mike  cảm ơn rất nhiều  <end> <pad>
# <start> so we turn to the field of vaccines  <end> <pad> <pad>
# <start> bây giờ  chúng ta chuyển sang lĩnh vực vaccine  <end>
# <start> that aposs a pretty hard act to beat  <end> <pad> <pad>
# <start> thật khó để đánh bại thành tích này  <end> <pad> <pad>
# <start> so  we had to do that gamble  <end> <pad> <pad>
# <start> vì vậy  chúng ta vẫn phải đánh cược  <end> <pad>
# <start> it was supposed to break  but that aposs okay  <end>
# <start> lẽ ra nó phải vỡ  nhưng cũng không sao  <end>
# <start> julie burstein  isn apost that a wonderful story  <end> <pad>
# <start> julie burstein  một câu chuyện tuyệt vời phải không  <end>
# <start> my office was just a few blocks away  <end> <pad> <pad>
# <start> văn phòng của tôi chỉ cách đó vài dãy nhà  <end>
# <start> the b iceberg broke off the ross ice shelf  <end> <pad>
# <start> tảng băng b vỡ ra khỏi bãi băng ross  <end> <pad>
# <start> i know a guy who did exactly that  <end> <pad> <pad>
# <start> tôi biết một người biết đích xác việc đó <end> <pad> <pad>
# <start> i don apost want opinions  i want knowledge  <end> <pad>
# <start> tôi không muốn ý kiến  tôi muốn kiến thức  <end>
# <start> what if there were a pure form of justice  <end> <pad>
# <start> nếu có một dạng thức thuần tuý của công lý  <end>
# <start> aristotle  in particular  he was not amused  <end> <pad>
# <start> aristotle  thực tế  ông không hài lòng  <end> <pad>
# <start> in fact  let aposs start right now  <end> <pad> <pad>
# <start> thực tế  hãy bắt đầu luôn bây giờ  <end> <pad>
# <start> it was remarkable  it took about one minute  <end> <pad>
# <start> hay lắm ý  mất khoảng một phút  <end> <pad> <pad>
# <start> there is a reflex called the lazarus reflex  <end> <pad> <pad>
# <start> phạn xạ này được gọi là phản xạ lazarus  <end> <pad>
# <start> and lo and behold  the hiccups went away  <end> <pad>
# <start> và lạ chưa kìa  anh đã ngừng nấc cụt  <end>
# <start> it was called the quot upsuck quot theory  <end> <pad> <pad>
# <start> nó được goi là thuyết quot hút ngược lên quot  <end>
# <start> and i got a copy of this dvd  <end> <pad> <pad>
# <start> và tôi có một bản sao của bộ dvd đó  <end>
# <start> why don apost you have the farmers do that  <end> <pad>
# <start> sao không để các tá điền làm điều đó  <end> <pad>
# <start> and the woman would have sex with it  <end> <pad> <pad>
# <start> và người phụ nữ sẽ quan hệ với nó  <end> <pad>
# <start> it also happens to be a relative of parsley  <end> <pad>
# <start> nó còn có họ hàng với rau mùi tây  <end> <pad>
# <start> the project is part art and part science  <end> <pad> <pad>
# <start> dự án mang tính nghệ thuật  khoa học  <end> <pad>
# <start> the tree was in part a catalyst for the project  <end>
# <start> cái cây này là chất xúc tác cho dự án  <end>
# <start> and then  of course  there aposs the lichens  <end>
# <start> và sau đó chúng tôi thấy địa y  <end> <pad> <pad>
# <start> and what aposs more  it aposs actually a tree  <end>
# <start> và nó thật sự là  cái cây  <end> <pad> <pad>
# <start> and actually  they aposre very quickly becoming a reality  <end>
# <start> đúng vậy  chúng đã sớm trở thành hiện thực <end> <pad>
# <start> and this has always been the case  throughout history  <end>
# <start> và điều này luôn luôn đúng trong mọi thời đại <end> <pad>
# <start> but i think the truth is the exact opposite  <end> <pad>
# <start> nhưng tôi nghĩ sự thật lại hoàn toàn trái ngược <end> <pad>
# <start> let aposs not succumb to the temptation to automate war  <end>
# <start> đừng để cám dỗ bởi chiến tranh tự động <end> <pad> <pad>
# <start> and this isn apost just a problem in britain  <end> <pad>
# <start> và vấn đề này không chỉ xảy ra ở anh  <end>
# <start> what is wrong with the people that we have chosen  <end>
# <start> hay với những người mà chúng tôi chọn  <end> <pad> <pad>
# <start> a lot goes to the uk  germany  <end> <pad> <pad>
# <start> rất nhiều được mang sang anh  đức  <end> <pad> <pad>
# <start> and carl norden is very firmly in the former camp  <end>
# <start> và carl nordon hoàn toàn nằm trong nhóm thứ nhất  <end>
# <start> is it because their weapons weren apost accurate  <end> <pad> <pad>
# <start> có phải vì vũ khí của họ không chính xác  <end>
# <start> it is this weapon of devastating accuracy and precision  <end> <pad>
# <start> nó là mộ vũ khí tàn phá chính xác  <end> <pad>
# <start> it gives you the kick out of taking risks  <end> <pad>
# <start> nó cho bạn một cú hích để liều  <end> <pad> <pad>
# <start> and a lot of them are actually pretty good  <end> <pad>
# <start> và chúng có thể làm điều này rất tốt  <end> <pad>
# <start> i heard their prayer and ate their bread  <end> <pad> <pad>
# <start> tôi nghe họ cầu nguyện và ăn bánh mì của họ <end>
# <start> this is hard  i feel guilty sometimes  <end> <pad> <pad>
# <start> rất khó  đôi lúc tôi cảm thấy tội lỗi  <end>
# <start> two  make your partner a real partner  <end> <pad> <pad>
# <start> hai  để bạn đời thục sự là bạn đời  <end>
# <start> and everyone kind of sat at the table  <end> <pad> <pad>
# <start> và mọi người đều ngồi vào bàn là việc  <end> <pad>
# <start> don apost you love that kind of thing from college  <end>
# <start> ai lại không thích những môn như thế ở trường  <end>
# <start> the three of us take this class together  <end> <pad> <pad>
# <start> ba người chúng tôi học chung môn này  <end> <pad> <pad>
# <start> but that one word made a really big difference  <end> <pad>
# <start> nhưng cái từ đó đã gây ảnh hưởng rất lớn  <end>
# <start> the bad news was that everyone liked howard  <end> <pad> <pad>
# <start> tin xấu là mọi người đều thích howard  <end> <pad> <pad>
# <start> you want to spend the day fishing with him  <end> <pad>
# <start> các bạn muốn đi câu cá cùng anh ấy  <end> <pad>
# <start> i said  quot what do you mean  quot <end> <pad>
# <start> tôi hỏi quot ý cô là sao  quot <end> <pad> <pad>
# <start> and what that means is that i argue  <end> <pad> <pad>
# <start> và điều đó có nghĩa là tôi tranh luận  <end> <pad>
# <start> that aposs the kind of argument we want  <end> <pad> <pad>
# <start> đó là các loại lập luận mà chúng ta muốn  <end>
# <start> there aposs the reasoner in arguments as proofs  <end> <pad> <pad>
# <start> có lý luận gia trong lập luận bằng chứng  <end> <pad>
# <start> it aposs a children aposs book for the ipad  <end> <pad>
# <start> đó là một cuốn sách trẻ em cho ipad  <end> <pad>
# <start> it aposs not the way i was brought up  <end> <pad>
# <start> đó không phải là cách tôi được nuôi nấng  <end> <pad>
# <start> now  she had no idea what to look for  <end>
# <start> cô ấy không biết phải tìm kiếm những gì  <end> <pad>
# <start> in fact  she need not have hurried  <end> <pad> <pad>
# <start> thực chất  cô ấy không cần phải vội  <end> <pad>
# <start> well  she had a fantastic model for thinking  <end> <pad>
# <start> cô ấy đã có một lối suy nghĩ rất lạ  <end>
# <start> alice and george were very good at conflict  <end> <pad> <pad>
# <start> alice and george rất giỏi trong tranh cãi  <end> <pad> <pad>
# <start> lots of snow in which to dig a den  <end> <pad>
# <start> rất nhiều tuyết để có thể đào  cái hang <end> <pad>
# <start> i always get goosebumps every time i see it  <end> <pad>
# <start> tôi luôn nổi da gà mỗi khi nhìn thấy nó  <end>
# <start> but at  feet  it aposs tough  <end> <pad> <pad>
# <start> ở độ cao  feet  quả là khắc nghiệt  <end>
# <start> dan buettner  how to live to be   <end> <pad>
# <start> dan buettner  làm sao để sống lâu   <end> <pad>
# <start> after that the effect of evolution completely dissipates  <end> <pad> <pad>
# <start> sau đó ảnh hưởng của tiến hoá hoàn toàn mất đi <end>
# <start> there is just too many things to go wrong  <end> <pad>
# <start> chỉ là có quá nhiều thứ có vấn đề  <end> <pad>
# <start> those cells turn themselves over once every eight years  <end> <pad>
# <start> những tế bào đó quay mình mỗi  năm  <end> <pad>
# <start> well  the same things happen to our cells  <end> <pad>
# <start> chuyện tương tự cũng diễn ra với tế bào  <end> <pad>
# <start> five times as many centenarians as we have in america  <end>
# <start> số người trên  gấp  lần ở mỹ  <end> <pad>
# <start> and one sixth the rate of cardiovascular disease  <end> <pad> <pad>
# <start> tỉ lệ bị mạch vành chỉ bằng     <end>
# <start> and then one day  boom  we retire  <end> <pad>
# <start> và  ngày  bùm  ta nghỉ hưu <end> <pad> <pad>
# <start> but that aposs because all the young people left  <end> <pad>
# <start> nhưng đó là vì người trẻ đã bỏ đi <end> <pad> <pad>
# <start> so  we turned to the data again  <end> <pad> <pad>
# <start> nên  chúng tôi quay lại với những số liệu  <end>
# <start> they take their diet directly from the bible  <end> <pad> <pad>
# <start> họ tuân theo chế độ ăn từ kinh thánh  <end> <pad>
# <start> this is a culture that has yielded ellsworth whareham  <end> <pad>
# <start> đây là nền văn hoá đã nuôi dưỡng ellsworth wheram  <end>
# <start> her grandson actually lives in the twin cities here  <end> <pad>
# <start> cháu trai của bà đang sống ở twin cities  <end> <pad>
# <start> the sardinians pray  the seventhday adventists pray  <end> <pad> <pad>
# <start> người sardinia cầu nguyện  người adventist cũng cầu nguyện <end> <pad>
# <start> he aposs almost like the banksy of the internet  <end> <pad>
# <start> anh ta gần giống như banksy của internet  <end> <pad> <pad>
# <start> it aposs  percent above the category average  <end> <pad> <pad>
# <start>  phần trăm ở trên mức trung bình ngành  <end> <pad>
# <start> there were  kinds of notes in america  <end> <pad> <pad>
# <start> đã có  các loại ghi chú ở mỹ  <end> <pad>
# <start> i still start every day practicing playing bach  <end> <pad> <pad>
# <start> tôi vẫn bắt đầu mỗi ngày bằng kéo nhạc của bach <end>
# <start> skylar tibbits  the emergence of quot d printing quot <end> <pad>
# <start> skylar tibbits  sự xuất hiện của quot in d quot <end>
# <start> and we built  of these glass beakers  <end> <pad> <pad>
# <start> và chúng tôi đã làm  lọ thuỷ tinh  <end> <pad>
# <start> you shake it hard and it breaks apart  <end> <pad> <pad>
# <start> bạn lắc nó thật mạnh và nó bị gẫy ra  <end>
# <start> and space is a great example of that  <end> <pad> <pad>
# <start> và không gian là một ví dụ lớn  <end> <pad> <pad>
# <start> i imagine what can be said with them  <end> <pad> <pad>
# <start> tôi tưởng tượng có thể nói với chúng những gì  <end>
# <start> so i aposll just let this chair come down  <end> <pad>
# <start> vậy nên  tôi sẽ chỉ để cái ghế xuống <end> <pad>
# <start> hetain patel  who am i  think again <end> <pad> <pad>
# <start> hetain patel  tôi là ai  hãy suy nghĩ lại <end>
# <start> i said  quot yes  so  quot <end> <pad> <pad>
# <start> tôi nói  quot đúng vậy  thì sao  quot <end>
# <start> quot i don apost have time for a stroke  quot <end>
# <start> quot tôi không có thời gian để tai biến  quot <end>
# <start> i am the lifeforce power of the universe  <end> <pad> <pad>
# <start> tôi là năng lượng sự sống của vũ trụ  <end> <pad>
# <start> and i thought that was an idea worth spreading  <end> <pad>
# <start> tôi nghĩ đó là một ý tưởng đáng lan toả  <end>
# <start> quot better immersion than to live untouched  quot <end> <pad> <pad>
# <start> quot sống hoà nhập còn hơn sống vô cảm  quot <end>
# <start> and i met them in the early apos s  <end> <pad>
# <start> và tôi đã gặp họ vào đầu những năm   <end>
# <start> so  why don apost you tell that story  <end> <pad>
# <start> vậy  tại sao bạn không kể chuyện đó  <end> <pad>
# <start> i played softball for five years growing up  <end> <pad> <pad>
# <start> tôi chơi bóng mềm trong năm năm tuổi thơ  <end> <pad>
# <start> and i said  quot no  come on  quot <end>
# <start> và tôi nói  quot không  coi nào  quot <end>
# <start> you can run with our women aposs track team  quot <end>
# <start> cô có thể chạy với đội nữ  quot <end> <pad> <pad>
# <start> it aposs now two years that you aposve been running  <end>
# <start> cô ấy bây giờ  đã chạy được hai năm  <end>
# <start> and so  here i am  never lost  <end> <pad>
# <start> và giờ ở đây tôi  không bao giờ thua  <end>
# <start> and i aposm sure of it  you know  <end> <pad>
# <start> và tôi chắc chắn  bạn biết đó  <end> <pad> <pad>
# <start> ss  why don apost you show them your legs  <end>
# <start> cheryl  sao cô không cho họ xem chân mình  <end>
# <start> ss  you got to pick your height  <end> <pad> <pad>
# <start> cheryl  bạn chọn chiều cao của mình  <end> <pad> <pad>
# <start> no  i aposve got so many legs in here  <end>
# <start> không  tôi có quá nhiều chân ở đây  <end> <pad>
# <start> these are  do you want to hold that actually  <end>
# <start> đây là những  bạn thực sự muốn giữ nó  <end>
# <start> am  yes  we aposll do that  <end> <pad> <pad>
# <start> am  vâng  chúng tôi sẽ làm điều đó  <end>
# <start> and this is just a silicon piece of skin  <end> <pad>
# <start> và nó chỉ là một miếng da silicon  <end> <pad> <pad>
# <start> i mean  they make ears for burn victims  <end> <pad>
# <start> họ làm cho tai cho nạn nhân phỏng  <end> <pad> <pad>
# <start> when i got out i had a choice  <end> <pad> <pad>
# <start> tới khi ra trường  tôi đã quyết định  <end> <pad>
# <start> rebecca mackinnon  let aposs take back the internet  <end> <pad>
# <start> rebecca mackinnon  hãy bàn lại về internet  <end> <pad> <pad>
# <start> today  things are a lot more subtle  quot <end> <pad>
# <start> ngày nay  mọi chuyện phức tạp hơn nhiều quot <end> <pad>
# <start> but that aposs only half of the story  <end> <pad> <pad>
# <start> nhưng đây mới chỉ là một nửa câu chuyện  <end> <pad>
# <start> we also are going to need political innovation  <end> <pad> <pad>
# <start> chúng ta cũng sẽ cần cuộc cải cách chính trị  <end>
# <start> at the moment  we still don apost know  <end> <pad>
# <start> trong lúc này  chúng ta vẫn chưa biết  <end> <pad>
# <start> sugata mitra  build a school in the cloud <end> <pad> <pad>
# <start> sugata mitra  xây dựng một ngôi trường trên mây <end> <pad>
# <start> what is going to be the future of learning  <end> <pad>
# <start> tương lai của việc học tập sẽ là gì  <end> <pad>
# <start> what are the kind of jobs that we have today  <end>
# <start> hiện tại chúng ta có các loại công việc gì  <end>
# <start> they aposre there in thousands in every office  <end> <pad> <pad>
# <start> có hàng ngàn máy vi tính trong mỗi văn phòng  <end>
# <start> i said  quot just like that  quot <end> <pad> <pad>
# <start> tôi trả lời  quot chỉ để thế thôi  quot <end>
# <start> quot and anyway  i am going away  quot <end> <pad>
# <start> quot mà thôi  thầy đi đây  quot <end> <pad> <pad>
# <start> so i left them for a couple of months  <end> <pad>
# <start> rồi tôi đã vắng mặt khoảng vài tháng  <end> <pad> <pad>
# <start> we look at it every single day  quot <end> <pad> <pad>
# <start> ngày nào tụi con cũng quan sát nó  quot <end> <pad>
# <start> so she says  quot what aposs that  quot <end> <pad>
# <start> cô ấy mới hỏi  quot cái gì  quot <end> <pad>
# <start> i got  in the first two weeks  <end> <pad> <pad>
# <start> tuần đầu tiên tôi nhận được  lời đồng ý  <end>
# <start> she goes on over skype and she sorts things out  <end>
# <start> bà sẽ bật skype và xử lý mọi việc  <end> <pad>
# <start> sm  a decade ahead of her time  <end> <pad> <pad>
# <start> một thập kỷ trước cả tương lai thưa quý vị  <end>
# <start> it will be called the school in the cloud  <end> <pad>
# <start> nó sẽ được gọi là quot ngôi trường trên mây quot <end>
# <start> the rest of it aposs from the cloud  <end> <pad> <pad>
# <start> các phần còn lại của nó đều từ đám mây  <end>
# <start> i aposll take you to the top of the himalayas  <end>
# <start> tôi sẽ đưa các bạn lên đỉnh núi himalayas  <end> <pad>
# <start> nathan wolfe  what aposs left to explore  <end> <pad> <pad>
# <start> nathan wolfe  còn gì để khám phá  <end> <pad> <pad>
# <start> basically we have no clue what this is  <end> <pad> <pad>
# <start> đơn giản là chúng tôi không có manh mối nào  <end>
# <start> at first we thought that perhaps this was artifact  <end> <pad>
# <start> đầu tiên chúng tôi nghĩ có lẽ đó là nhân tạo <end>
# <start> six is a tiny and very sad black hole  <end> <pad>
# <start> số sáu là một cái hố nhỏ bé và buồn rầu <end>
# <start> it aposs a multiplication of two prime numbers  <end> <pad> <pad>
# <start> đó là một phép nhân của hai số nguyên tố <end> <pad>
# <start> another example  a little bit more mathematical  <end> <pad> <pad>
# <start> một ví dụ khác thiên về toán học hơn chút nữa <end>
# <start> let aposs have a look at the third question  <end> <pad>
# <start> giờ hãy nhìn vào câu hỏi thứ ba  <end> <pad> <pad>
# <start> it aposs a line from a poem by john keats  <end>
# <start> là một dòng trong bài thơ viết bởi john keats  <end>
# <start> i look  both are of the male sex  <end> <pad>
# <start> tôi nhìn lại  cả hai đúng là loài đực  <end>
# <start> and there are nine other winners who get prizes  <end> <pad>
# <start> và có  người nữa nhận giải thưởng  <end> <pad> <pad>
# <start> dan  where are you  dan ariely  <end> <pad> <pad>
# <start> dan  anh ở đâu  dan ariely  <end> <pad> <pad>
# <start> may i have my duck back  please  <end> <pad> <pad>
# <start> có thể cho tôi xin lại con vịt được không  <end>
# <start> dennis hong  making a car for blind drivers <end> <pad> <pad>
# <start> dennis hong  xe hơi dành cho người khiếm thị <end> <pad>
# <start> now the first interface is called a drivegrip  <end> <pad> <pad>
# <start> giao diện đầu tiên được gọi là drivegrip  <end> <pad> <pad>
# <start> we call this the quot backseatdriver problem  quot <end> <pad> <pad>
# <start> chúng tôi gọi đó là vấn đề người lái sau  <end>
# <start> he aposs coming up to the grandstand  fellow federationists  <end>
# <start> anh ấy đang đi tới khán đài  anh federistas  <end>
# <start> dennis hong  i aposm so happy for you  <end> <pad>
# <start> dennis hong  tôi thấy hạnh phúc cho bạn  <end> <pad>
# <start> how are we going to issue driver aposs licenses  <end> <pad>
# <start> chúng ta sẽ làm thế nào để cấp bằng lái  <end>
# <start> and in many ways  it always has been  <end> <pad>
# <start> và theo nhiều cách  nó đã luôn như vậy  <end>
# <start> we think the entire tumor is out  quot <end> <pad> <pad>
# <start> chúng tôi nghĩ toàn bộ khối u đã tách bỏ quot <end>
# <start> there aposs still cancer in your patient  quot <end> <pad> <pad>
# <start> vẫn còn ung thư trong bệnh nhân  quot <end> <pad> <pad>
# <start> i couldn apost when i was working on this  <end> <pad>
# <start> tôi không thể khi làm việc với nó  <end> <pad> <pad>
# <start> patients are still on the operating room table  <end> <pad> <pad>
# <start> những bệnh nhân vẫn ở trên bàn mổ  <end> <pad> <pad>
# <start> so it aposs very important to avoid inadvertent injury  <end> <pad>
# <start> rất quan trọng để tránh những vết thương vô ý <end> <pad>
# <start> and what i aposm talking about are nerves  <end> <pad> <pad>
# <start> và tôi đang nói về những dây thần kinh  <end> <pad>
# <start> we haven apost had that many complications  quot <end> <pad> <pad>
# <start> chúng tôi không có nhiều những phức tạp  quot <end> <pad>
# <start> you see what looks like little medusa heads coming out  <end>
# <start> bạn thấy giống như nhiều đầu rắn đang đi ra  <end>
# <start> we aposve been able to see every single nerve  <end> <pad>
# <start> chúng ta cũng có thể thấy một sợi thần kinh  <end>
# <start> that white portion there is easy to see  <end> <pad> <pad>
# <start> đó là phần trắng rất dễ để thấy  <end> <pad> <pad>
# <start> but what about the part that goes into the tumor  <end>
# <start> những phần xung quanh khối u thì sao  <end> <pad> <pad>
# <start> i aposd like to leave you with this final thought  <end>
# <start> tôi muốn gửi lại thông điệp cuối cùng  <end> <pad> <pad>
# <start> her friend says  quot buy it already  quot <end> <pad>
# <start> bạn cô ta nói  quot mua nó cho rồi quot <end>
# <start> but if you go to santee alley  yeah  <end> <pad>
# <start> nhưng nếu như bạn đi đến santee alley  ah vâng <end>
# <start> it forced him to be a little more innovative  <end> <pad>
# <start> nó buộc anh ta phải một chút thêm sáng tạo  <end>
# <start> this is not unlike the world of comedy  <end> <pad> <pad>
# <start> đây không giống với thới gới hài kịch  <end> <pad> <pad>
# <start> but this has not stopped diane von furstenberg  <end> <pad> <pad>
# <start> nhưng điều đó không thể dừng được diane von furstenberg  <end>
# <start> that is a very difficult question to answer  <end> <pad> <pad>
# <start> thật khó để có câu trả lời nó  <end> <pad> <pad>
# <start> it aposs a utilitarian article  that aposs why  <end> <pad>
# <start> nó là một tiêu tề của thực dụng  <end> <pad> <pad>
# <start> same with furniture  it aposs too utilitarian  <end> <pad> <pad>
# <start> cũng vậy với đồ đạc  nó quá thực dụng  <end>
# <start> then no  it does not deserve protection  <end> <pad> <pad>
# <start> thế thì không  nó không xứng được bảo vệ  <end>
# <start> the other one is  is it an idea  <end> <pad>
# <start> còn cái khác là  nó là ý kiến  <end> <pad>
# <start> it aposs held every two years in burma  <end> <pad> <pad>
# <start> nó được tổ chức định kỳ  năm ở burma  <end>
# <start> so  welcome to oxford  ladies and gentlemen  <end> <pad>
# <start> kính thưa quý vị  chào mừng tới oxford  <end> <pad>
# <start> what ataturk realized actually is two very fundamental things  <end> <pad>
# <start> ataturk nhận ra  điều rất căn bản  <end> <pad> <pad>
# <start> now  we basically have to change our views slightly  <end>
# <start> chúng ta phải thay đổi cách nhìn nhận  chút  <end>
# <start> i would say it aposs a work of genius  <end> <pad>
# <start> theo tôi đó là công việc của thiên tài  <end> <pad>
# <start> but a six is very different from a nine  <end> <pad>
# <start> nhưng  là   và  là   <end> <pad>
# <start> and it had a chilling effect on me  <end> <pad> <pad>
# <start> và nó có một ảnh hưởng lớn với tôi  <end> <pad>
# <start> what happens is that circular logic takes over  <end> <pad> <pad>
# <start> và chuyện xảy ra là một lô gíc vòng quanh  <end>
# <start> all i have to do is humbly follow  <end> <pad> <pad>
# <start> và điều duy nhất tôi phải làm là vâng theo  <end>
# <start> we aposre beginning to look inside the brain  <end> <pad> <pad>
# <start> chúng ta đang bắt đầu nhìn vào trong bộ não  <end>
# <start> some things worked  some things didn apost  <end> <pad> <pad>
# <start> vài thứ đã hoạt động  vài thứ không  <end> <pad>
# <start> but i did say no to the blue hair  <end> <pad>
# <start> nhưng tôi đã nói không với màu tóc xanh dương  <end>
# <start> now imagine you have to cross a street  <end> <pad> <pad>
# <start> và bây giờ tưởng tượng bạn phải băng qua đường  <end>
# <start>  years later i gained my sight back  <end> <pad> <pad>
# <start>  năm sau tôi lấy lại được ánh sáng  <end> <pad>
# <start> they removed a hematoma from behind my eye  <end> <pad> <pad>
# <start> họ lấy đi khối máu tụ từ dưới mắt tôi  <end>
# <start> asher hasan  my message of peace from pakistan <end> <pad> <pad>
# <start> thông điệp hoà bình của asher hasan từ pakistan  <end> <pad>
# <start> but there are many other dimensions to pakistan  <end> <pad> <pad>
# <start> nhưng còn có nhiều góc độ khác với pakistan  <end> <pad>
# <start> my name is abdul khan  i come from peshawar  <end>
# <start> tên tôi là abdul khan  tôi đến từ peshwar  <end>
# <start> do you see me simply smothered in cloth  <end> <pad> <pad>
# <start> bạn có thấy tôi được quần áo vây kín không  <end>
# <start> they went through a lot to get here  <end> <pad> <pad>
# <start> họ trải qua rất nhiều đề đi đến đó  <end> <pad>
# <start> would the pakistanis please just stand up please  <end> <pad> <pad>
# <start> những người pakistan xin vui lòng đứng dậy được không  <end>
# <start> so  quot yo napot  pacak  quot <end> <pad> <pad>
# <start> vậy  quot yo napot  pacak  quot <end> <pad> <pad>
# <start> quot no  i reckon i don apost  quot <end> <pad>
# <start> quot không  tôi nghĩ là không  quot <end> <pad> <pad>
# <start> i aposm going to talk about your mindset  <end> <pad> <pad>
# <start> tôi sắp nói về cách suy nghĩ của bạn  <end> <pad>
# <start> but then you know  i press them like this  <end>
# <start> và bạn biết đấy  tôi thúc họ như thế này <end>
# <start> and you can see we still have afghanistan down here  <end>
# <start> các bạn vẫn có thể thấy afghanistan dưới này <end> <pad> <pad>
# <start> income per person  i can put that here  <end> <pad>
# <start> thu nhập của mỗi người  tôi đặt ở đây  <end>
# <start> and i can find united states up there  <end> <pad> <pad>
# <start> và tôi có thể thấy hoa kỳ trên đó <end> <pad> <pad>
# <start> and then it will continue forward like this  <end> <pad> <pad>
# <start> và rồi nó vẫn tiếp tục hướng đến thế này  <end>
# <start> east europe  latin america  and oecd countries  <end> <pad>
# <start> đông âu  mỹ latinh  các nước oecd  <end> <pad>
# <start> at this point i decided to make a pause  <end> <pad>
# <start> đến đây thì tôi quyết định viết một lá thư <end> <pad>
# <start> and i aposm not paid to come here  no  <end>
# <start> tôi cũng chẳng được trả tiền để đến đây  <end> <pad>
# <start> they vaccinated the kids  they get better water  <end> <pad>
# <start> tiêm vắcxin cho trẻ em  nguồn nước cũng tốt hơn <end>
# <start> i run sweden the same  year period  <end> <pad> <pad>
# <start> đó là giai đoạn  năm của thuỵ điển  <end> <pad>
# <start> but then they started to grow their economy  <end> <pad> <pad>
# <start> và sau đó họ bắt đầu phát triển kinh tế  <end>
# <start> about  percent of the adult population are infected  <end> <pad>
# <start> khoảng   dân số trưởng thành bị nhiễm  <end> <pad>
# <start> because here  in congo  there is war  <end> <pad>
# <start> bởi ở đó  congo  có chiến tranh  <end> <pad>
# <start> and here  in zambia  there is peace  <end> <pad>
# <start> và ở đây  zambia  đang hoà bình  <end> <pad>
# <start> and it aposs really different within each country  <end> <pad> <pad>
# <start> đó là sự khác biệt trong một đất nước  <end> <pad>
# <start> they are still as poor as they aposve ever been  <end>
# <start> họ vẫn nghèo như họ đã và đang  <end> <pad> <pad>
# <start> i think it was a tactic of survival  <end> <pad> <pad>
# <start> tôi nghĩ đó là cách để mà tồn tại  <end> <pad>
# <start> they were chanting  quot we want peace  <end> <pad> <pad>
# <start> họ đã hát  quot chúng tôi muốn hoà bình  <end>
# <start> i didn apost come from a military family  <end> <pad> <pad>
# <start> tôi không xuất thân từ một gia đình nhà lính  <end>
# <start> i aposm going to send you to military school  quot <end>
# <start> mẹ sẽ gửi con vào trường quân sự  quot <end> <pad>
# <start> there really wasn apost a whole lot going on  <end> <pad>
# <start> không có một cuộc chiến nào lúc bấy giờ  <end> <pad>
# <start> i didn apost ever feel like i was in danger  <end>
# <start> tôi chưa từng cảm thấy mình trong vòng nguy hiểm  <end>
# <start> they signed up because of a sense of obligation  <end> <pad>
# <start> họ nhập ngũ vì đó là nghĩa vụ  <end> <pad> <pad>
# <start> they signed up because they wanted some form of revenge  <end>
# <start> họ nhập ngũ vì họ muốn trả thù  <end> <pad> <pad>
# <start> they signed for a whole collection of different reasons  <end> <pad>
# <start> họ nhập ngũ vì rất nhiều lí do khác nhau  <end>
# <start> i just said it because it sounded right  <end> <pad> <pad>
# <start> tôi nói nó vì nó nghe hợp lí  <end> <pad> <pad>
# <start> it keeps playing out in all of our minds  <end> <pad>
# <start> tiếp tục trong suy nghĩ của chúng tôi  <end> <pad> <pad>
# <start> it plays out in all of our memories  <end> <pad> <pad>
# <start> tiếp tục trong những kí ức của chúng tôi  <end> <pad>
# <start> it plays out in all of our emotions  <end> <pad> <pad>
# <start> tiếp tục trong cảm xúc của chúng tôi  <end> <pad> <pad>
# <start> dorothy  on the right  lives in rural kenya  <end>
# <start> dorothy  bên phải  sống ở vùng nông thôn kenya <end>
# <start> it sounds more inflationary already  doesn apost it  <end> <pad>
# <start> điều này nghe có vẻ lạm phát rồi nhỉ  <end> <pad>
# <start> to me  it aposs not that clear  <end> <pad> <pad>
# <start> đối với tôi điều đó không rõ ràng  <end> <pad> <pad>
# <start> but it aposs very simple  it aposs very simplistic  <end>
# <start> nhưng nó rất đơn giản  rất thô sơ  <end> <pad>
# <start> life also has a kind of inheritable information  <end> <pad> <pad>
# <start> sự sống còn phải có thông tin di truyền  <end> <pad>
# <start> we aposre going to make two different kinds  <end> <pad> <pad>
# <start> chúng ta sẽ làm hai loại khác nhau  <end> <pad> <pad>
# <start> there aposs a protocell ab now in this system  <end> <pad>
# <start> giờ ta có tế bào ab trong hệ thống này  <end>
# <start> think of it like a primordial ooze  okay  <end> <pad>
# <start> xem nó như một chất bùn nguyên thuỷ nhé  <end> <pad>
# <start> cameron sinclair  my wish  a call for opensource architecture <end>
# <start> cameron sinclair bàn về kiến trúc mã nguồn mở <end> <pad> <pad>
# <start> we just don apost know how to show this  quot <end>
# <start> chỉ là không biết làm sao để thực hiện nó quot <end>
# <start> that aposs not because i aposm a treehugging green person  <end>
# <start> không phải vì tôi là người yêu cây xanh cuồng tín <end>
# <start> you have to know where your energy is coming from  <end>
# <start> anh cần biết năng lượng của mình từ đâu mà có <end>
# <start> i can see chris looking at me slyly  <end> <pad> <pad>
# <start> tôi có thể thấy chris nhìn tôi chớp chớp <end> <pad> <pad>
# <start> it aposs built by the parents of the kids  <end> <pad>
# <start> ngôi trường được xây dựng bởi các phụ huynh <end> <pad> <pad>
# <start> this is a rehabbed home  done in four days  <end>
# <start> đây là ngôi nhà  hoàn thành trong  ngày <end> <pad>
# <start> so this is all done in the last two years  <end>
# <start> tất cả các công trình này đc làm trong  năm <end>
# <start> and i want this whole thing to work multilingually  <end> <pad>
# <start> và tôi muốn làm việc trong môi trường đa ngôn ngữ <end>
# <start> i aposm fed up of talking about making change  <end> <pad>
# <start> tôi chán ngấy phải nói về tạo ra sự thay đổi <end>
# <start> i will give points for those who know it  <end> <pad>
# <start> tôi sẽ tặng điểm cho những ai biết về điều đó <end>
# <start> this is the fedex delivery guy of the cell  <end> <pad>
# <start> đây là anh chàng chuyển phát fedex của tế bào  <end>
# <start> it aposs given to you  it aposs a gift  <end>
# <start> nó được ban tặng  là một món quà  <end> <pad>
# <start> look at the faces of people whom you meet  <end> <pad>
# <start> hãy nhìn những gương mặt mà bạn đã gặp gỡ  <end>
# <start> this is the second day in rockett aposs life  <end> <pad>
# <start> đây là ngày thứ hai trong cuộc đời rockett  <end> <pad>
# <start> rockett  hi miko  what aposs going on  <end> <pad>
# <start> rockett  hi miko  có gì không  <end> <pad> <pad>
# <start> it was like having an enormous new toy  <end> <pad> <pad>
# <start> nhưng nó như có một món đồ chơi mới  <end> <pad>
# <start> just being out on the street was exhilarating  <end> <pad> <pad>
# <start> chỉ ra ngoài phố cũng đã rất tuyệt vời  <end> <pad>
# <start> and you know the reason why  of course  <end> <pad>
# <start> và tất nhiên mọi người cũng biết lý do tại sao <end>
# <start> this is more serious than maybe editorial cartooning  <end> <pad> <pad>
# <start> việc này hệ trọng hơn là biên tập hoạt hình  <end>
# <start> this is the future of journalism  i think  <end> <pad>
# <start> tôi nghĩ đây là tương lai của báo chí <end> <pad> <pad>
# <start> and i aposm very proud of what they did  <end> <pad>
# <start> tôi rất tự hào về những gì họ đã làm  <end>
# <start> and i didn apost ask them to do nice cartoons  <end>
# <start> và tôi cũng không yêu cầu họ vẽ thật đẹp  <end>
# <start> in lebanon  it was not a book  <end> <pad> <pad>
# <start> ở libăng  không phải là quyểng sách  <end> <pad> <pad>
# <start> and so she set about to make it so  <end> <pad>
# <start> và cô bé tự bảo mình làm việc đó  <end> <pad>
# <start> well  guess what  i won  hooray  <end> <pad>
# <start> đoán xem  tôi đã thắng  hura  <end> <pad> <pad>
# <start> this is birgitta jónsdóttir  she aposs an icelandic mp  <end>
# <start> đây là birgitta jónsdóttir  đại biểu quốc hội iceland  <end>
# <start> skepticism  because you must always be challenging  <end> <pad> <pad>
# <start> đa nghi  vì bạn phải luôn thách thức  <end> <pad>
# <start> at the moment our rights are incredibly weak  <end> <pad> <pad>
# <start> lúc này quyền của chúng ta cực kỳ yếu  <end> <pad>
# <start> it was just  quot because i say so  <end> <pad>
# <start> kiểu như là  quot vì tôi nói thế  <end> <pad>
# <start> they aposre far more efficient in terms of energy  <end> <pad>
# <start> chúng hiệu quả hơn nhiều về mặt năng lượng  <end> <pad>
# <start> the first two are the macrobot and decibot  <end> <pad> <pad>
# <start> hai dự án đầu tiên là macrobot và decibot  <end> <pad>
# <start> so basically you have a chain of elements  <end> <pad> <pad>
# <start> đơn giản là bạn có một chuỗi các nguyên tố  <end>
# <start> therefore  it must be good for the environment  <end> <pad>
# <start> ta đã cho rằng lựa chọn này tốt cho môi trường <end>
# <start> and we aposve busted a bunch of myths  <end> <pad> <pad>
# <start> chúng ta phá bỏ được hàng ngàn bí ẩn <end> <pad> <pad>
# <start> forty percent food waste is a major problem  <end> <pad> <pad>
# <start>   đồ ăn thừa thật sự là vấn đề lớn <end>
# <start> they have so much locked up inside them  <end> <pad> <pad>
# <start> điện thoại có quá nhiều chi tiết bên trong <end> <pad> <pad>
# <start> we want something  therefore we buy it  <end> <pad> <pad>
# <start> muốn món gì đó thì chỉ đơn giản là mua nó <end>
# <start> benoit mandelbrot  fractals and the art of roughness <end> <pad> <pad>
# <start> benoit mandelbrot  fractal và nghệ thuật hỗn độn <end> <pad> <pad>
# <start> so let me show you a few objects  <end> <pad> <pad>
# <start> tôi sẽ cho quí vị xem một vài vật thể  <end>
# <start> now  what did humanity do with that  <end> <pad> <pad>
# <start> vậy  nhân loại đã làm gì với nó  <end> <pad>
# <start> i aposve been looking at these things for so long  <end>
# <start> tôi đã tìm kiếm những thứ này từ lâu  <end> <pad>
# <start> what aposs the length of the coastline of these lakes  <end>
# <start> chiều dài của bờ hồ này là bao nhiêu  <end> <pad>
# <start> what good is that  to know these things  <end> <pad>
# <start> biết những thứ này thì được gì nhỉ  <end> <pad> <pad>
# <start> and at the end  you get things like that  <end>
# <start> và cuối cùng bạn thu được thứ như thế này  <end>
# <start> this cloud is completely   percent artificial  <end> <pad> <pad>
# <start> đám mây đã hoàn thành    nhân tạo  <end>
# <start> the seer of clouds had to take account of it  <end>
# <start> hình dạng của đám mây phải cân nhắc đến nó  <end>
# <start> now  here is another thing which is rather interesting  <end>
# <start> đây là một thứ thú vị không kém  <end> <pad> <pad>
# <start> and well  it aposs a story unto itself  <end> <pad>
# <start> và  bản thân nó là một câu chuyện  <end> <pad>
# <start> the great painter hokusai knew it very well  <end> <pad> <pad>
# <start> hoạ sĩ vĩ đại hokusai biết điều này rất rõ  <end>
# <start> i see  it aposs an island  quot <end> <pad> <pad>
# <start> tôi thấy rồi  đó là một hòn đảo  quot <end>
# <start> long measurements  big brownian motions    <end> <pad> <pad>
# <start> số đo dài  chuyển động brown lớn   <end> <pad>
# <start> they got together  and together they had the proof  <end>
# <start> họ cùng hợp tác  và cùng chứng minh  <end> <pad>
# <start> well  here are the curves for it  <end> <pad> <pad>
# <start> đây là đường cong biểu thị điều đó  <end> <pad> <pad>
# <start> and after the war  i saw an uncle again  <end>
# <start> sau chiến tranh  tôi gặp lại một người chú  <end>
# <start> i don apost want to explain these things  <end> <pad> <pad>
# <start> tôi không muốn giải thích những thứ này  <end> <pad> <pad>
# <start> that aposs what aposs so complicated about war  <end> <pad> <pad>
# <start> cái phức tạp về chiến tranh là ở chỗ đó  <end>
# <start> they never even got out of their clothes  <end> <pad> <pad>
# <start> họ thậm chí không bao giờ cởi bỏ quân phục  <end>
# <start> they burned them and got a new set  <end> <pad> <pad>
# <start> họ đốt nó đi  và nhận một bộ mới  <end>
# <start> there was no communication with the outside world up there  <end>
# <start> không có liên lạc gì với thế giới bên ngoài  <end>
# <start> it aposs almost a slightly altered state of mind  <end> <pad>
# <start> gần như não trạng có sự thay đổi  <end> <pad> <pad>
# <start> half a second later  i heard dutdutdutdutduh  <end> <pad> <pad>
# <start> nửa giây sau  tôi mới nghe tiếng đút đút  <end>
# <start> the boys are up there for a year  <end> <pad> <pad>
# <start> họ làm nhiệm vụ như thế cả năm  <end> <pad> <pad>
# <start> i aposm still very good friends with him  <end> <pad> <pad>
# <start> hiện giờ chúng tôi vẫn thân thiết với nhau  <end> <pad>
# <start> it was in the middle of a huge firefight  <end> <pad>
# <start> đó là giữa lúc đấu súng ác liệt  <end> <pad> <pad>
# <start> many of you have probably read quot the iliad  quot <end>
# <start> nhiều người trong các bạn hẳn đã đọc iliad <end> <pad> <pad>
# <start> it aposs to keep the men around him alive  <end> <pad>
# <start> là giữ những người xung quanh anh sống sót  <end> <pad>
# <start> it aposs to pacify the village that he works in  <end>
# <start> là dẹp loạn tại ngôi làng nơi anh làm việc  <end>
# <start> they aposve eaten together  they aposve bled together  <end> <pad>
# <start> họ ăn chung  họ đổ máu cùng nhau  <end> <pad>
# <start> i broke five ribs on my left side  <end> <pad> <pad>
# <start> xương sườn bên trái bị gãy  cái  <end> <pad> <pad>
# <start> i broke my right arm  i broke my collarbone  <end>
# <start> tay phải bị và xương đòn bị gãy  <end> <pad> <pad>
# <start> quot no  it aposs too hard  quot <end> <pad> <pad>
# <start> quot không  điều này quá khó khăn  quot <end> <pad>
# <start> i tried to grasp what she was saying  <end> <pad> <pad>
# <start> tôi cố nắm bắt những gì bác sỹ nói <end> <pad> <pad>
# <start> after six months  it was time to go home  <end>
# <start> sau  tháng  đã đến lúc được về nhà  <end>
# <start> i felt so incredibly grateful for my life  <end> <pad> <pad>
# <start> tôi cảm thấy biết ơn cuộc sống vô cùng  <end> <pad>
# <start> you aposre in a wheelchair  that aposs normal  <end> <pad>
# <start> bạn phải ngồi trên xe lăn  bình thường  <end> <pad>
# <start> and i took the controls  and i was flying  <end>
# <start> tôi nắm lấy bộ điều khiển và bay  <end> <pad> <pad>
# <start> why not learn to fly upside down  quot <end> <pad> <pad>
# <start> sao không học lái máy bay nhào lộn  quot <end> <pad>
# <start> hans rosling  the best stats you aposve ever seen <end> <pad>
# <start> thuyết trình của hans rosling về thống kê dữ liệu <end> <pad>
# <start> this country over here is china  this is india  <end>
# <start> nước này là trung quốc  đây là ấn độ <end> <pad>
# <start> but a huge difference between afghanistan and sri lanka  <end> <pad>
# <start> có chênh lệch rất lớn giữa afghanistan và sri lanka  <end>
# <start> and sheikh sayed did that in a fairly good way  <end>
# <start> và sheikh sayed đã làm điều đó khá tốt  <end> <pad>
# <start> and that aposs a quite clever guy  huh  <end> <pad>
# <start>  và ông ta quả là khôn khéo phải không  <end>
# <start> now notice  i aposm not talking about government  <end> <pad>
# <start> hãy chú ý  tôi không nói về chính phủ <end> <pad>
# <start> of course they are  they are a mercantilist nation  <end>
# <start> và dĩ nhiên họ là một quốc gia hám lợi <end> <pad>
# <start> the interrelationship of nations  well it aposs always existed  <end>
# <start> mối liên hệ giữa các quốc gia luôn tồn tại <end> <pad>
# <start> lehman brothers goes down  the whole lot collapses  <end> <pad>
# <start> lehman brothers sụp đổ  tất cả đều sụp đổ <end> <pad>
# <start> we are all now deeply  deeply  deeply interconnected  <end>
# <start> chúng ta liên kết với nhau rất rất chặt chẽ <end> <pad>
# <start> that was when the enemy was outside the walls  <end> <pad>
# <start> đó là khi quân địch ở ngoài bức tường <end> <pad> <pad>
# <start> you understand that in industry  governments don apost  <end> <pad>
# <start> bạn hiểu điều đó nhưng chính phủ thì không  <end> <pad>
# <start> and these are not really a people oppressed by poverty  <end>
# <start> và họ không phải những người bị nghèo đói hành hạ <end>
# <start> education is the main event that can happen in cities  <end>
# <start> giáo dục là vấn đề chính tại các thành phố  <end>
# <start> what aposs going on in the street in mumbai  <end> <pad>
# <start> trên đường phố ở mumbai có những gì  <end> <pad> <pad>
# <start> so what i aposm going to do is play this  <end>
# <start> bởi vì điều mà tôi sắp trình diễn sau đây <end> <pad>
# <start> this is the song from the ted talks online  <end> <pad>
# <start> là đoạn nhạc trong những video của ted talk online  <end>
# <start> ken robinson  good morning  how are you  <end> <pad>
# <start> ken robinson  chào buổi sáng  bạn khoẻ không  <end>
# <start> julian treasure  i call this the mixer  <end> <pad> <pad>
# <start> julian treasure  tôi gọi nó là bộ mixer  <end> <pad>
# <start> dan ellsey  i have always loved music  <end> <pad> <pad>
# <start> dan ellsey  tôi luôn yêu thích âm nhạc  <end> <pad>
# <start> mark ronson  this is my favorite part  <end> <pad> <pad>
# <start> mark ronson  đây là phần tôi thích nhất  <end> <pad>
# <start> you gotta have doorstops  that aposs important  <end> <pad> <pad>
# <start> bạn phải có đồ chặn cửa  nó rất quan trọng <end>
# <start> tm  we all love music a great deal  <end> <pad>
# <start> tm  chúng ta đều rất yêu âm nhạc  <end> <pad>
# <start> i aposd like to play a song for you  <end> <pad>
# <start> tôi muốn chơi một bản nhạc cho các bạn  <end> <pad>
# <start> it runs a risk of being completely bland  <end> <pad> <pad>
# ...
# <start> và chúng ta cần đơn giản hoá nó  <end> <pad> <pad>
# <start> it doesn apost count if it was you  sir  <end>
# <start> không tính nếu người ấy là bạn nhé  <end> <pad> <pad>
# <start> so i thought  got to talk about that  <end> <pad>
# <start> vì vậy  tôi phải nói điều đó ra  <end> <pad>
# <start> we aposll get back to that a little bit later  <end>
# <start> chúng ta sẽ quay lại trong chốc lát  <end> <pad> <pad>
# <start> and there aposs really no argument about this among anthropologists  <end>
# <start> không có tranh cãi về vấn đề này  <end> <pad> <pad>
# <start> in a huntergatherer band  there are no strangers  <end> <pad>
# <start> trong một cộng đồng săn bắt  hái lượm  <end> <pad>
# <start> i aposm just saying it wasn apost sexually exclusive  <end> <pad>
# <start> tôi chỉ nói rằng không có độc quyền tình dục  <end>
# <start> that one took a minute to sink in  huh  <end>
# <start> cũng phải đến một phút sau mới hiểu đấy nhỉ  <end>
# <start> there aposs a lot to talk about in this chart  <end>
# <start> có thể bàn luận rất nhiều về biểu đồ này  <end>
# <start> we share that ratio with chimps and bonobos  <end> <pad> <pad>
# <start> tinh tinh và bonobo có cùng tỉ lệ này  <end> <pad>
# <start> now  this evidence goes way beyond anatomy  <end> <pad> <pad>
# <start> bằng chứng này không chỉ có trong giải phẫu học <end> <pad>
# <start> thank you  communicated powerfully  thanks a lot  <end> <pad>
# <start> xin cảm ơn anh  diễn đạt thật mạnh mẽ  <end>
# <start> molly stevens  a new way to grow bone <end> <pad> <pad>
# <start> molly stevens  phương pháp mới để tái tạo xương <end> <pad>
# <start> we aposre not quite sure why they did it  <end> <pad>
# <start> chúng ta không rõ vì sao họ làm thế  <end> <pad>
# <start> but it also had other very nice properties  <end> <pad> <pad>
# <start> nhưng nó cũng có thuộc tính tốt đẹp khác  <end> <pad>
# <start> their very purpose was to perform a mechanical function  <end> <pad>
# <start> mục đích là thực hiện chức năng cơ học  <end> <pad>
# <start> we aposve lots of blood vessels in there  <end> <pad> <pad>
# <start> chúng ta có rất nhiều các mạch máu ở đó  <end>
# <start> rupal patel  synthetic voices  as unique as fingerprints <end> <pad>
# <start> rupal patel  giọng nói cũng độc đáo như vân tay <end>
# <start> that aposs what i aposd like to share with you  <end>
# <start> đó là câu chuyện tôi muốn chia sẻ  <end> <pad> <pad>
# <start> it aposs beautiful  it aposs exactly that  <end> <pad> <pad>
# <start> miêu tả tài tình  chính xác là vậy  <end> <pad>
# <start> samantha  this voice is only for me  <end> <pad> <pad>
# <start> samantha  giọng nói này chỉ dành cho tôi  <end> <pad>
# <start> but there aposs so much more work to be done  <end>
# <start> nhưng vẫn còn rất nhiều việc phải làm khác  <end> <pad>
# <start> they say that giving blood can save lives  <end> <pad> <pad>
# <start> có người đã nói hiến máu có thể cứu người  <end>
# <start> let me remind you what we already know  <end> <pad> <pad>
# <start> để tôi nhắc lại điều chúng ta đã biết  <end> <pad>
# <start> one example is near and dear to our hearts  <end> <pad>
# <start> đây là  ví dụ gần gũi với chúng ta  <end>
# <start> in blue  we see the msci world  <end> <pad> <pad>
# <start> chúng ta thấy msci world biểu hiện bằng màu xanh  <end>
# <start> this is why we are concerned with esg  quot <end> <pad>
# <start> đó là lý do chúng tôi quan tâm đến esg quot <end>
# <start> so i aposm not talking about tradeoffs here  <end> <pad> <pad>
# <start> và tôi đang nói về sự cân bằng ở đây  <end>
# <start> i mean  a really lot of it  <end> <pad> <pad>
# <start> ý tôi là thực sự rất nhiều tiền  <end> <pad> <pad>
# <start> so this is the sketch of the two states  <end> <pad>
# <start> và đây là bản phác của  trạng thái  <end> <pad>
# <start> seated in this audience are  small figures  <end> <pad> <pad>
# <start> ngồi trên khán đài là  bức tượng nhỏ  <end> <pad>
# <start> it comes out of the idea of a window  <end> <pad>
# <start> nó đến từ ý tưởng về cái cửa sổ  <end> <pad>
# <start> what do i mean by the informal in this case  <end>
# <start> quot không chính quy quot nghĩa là gì  <end> <pad> <pad>
# <start> so these are houses waiting to cross the border  <end> <pad>
# <start> đây là những ngội nhà chờ được vượt biên  <end> <pad>
# <start> with shovels in hand  they started to dig  <end> <pad>
# <start> với xẻng trong tay  họ bắt đầu đào  <end> <pad>
# <start> two weeks later  the police stopped them  <end> <pad> <pad>
# <start> hai tuần sau  cảnh sát bắt họ ngừng lại  <end>
# <start> they came to the city attorney aposs office  <end> <pad> <pad>
# <start> chúng đến văn phòng luật sư thành phố  <end> <pad> <pad>
# <start> server  may i help you  sir  <end> <pad> <pad>
# <start> bồi bàn  tôi có thể giúp gì cho ngài  <end>
# <start> in the beginning  the system is disorganized  <end> <pad> <pad>
# <start> ban đầu  hệ thống mất trật tự  <end> <pad> <pad>
# <start> so we took er to the evaluation room  <end> <pad> <pad>
# <start> do vậy chúng tôi đem er đến phòng đánh giá  <end>
# <start> mostly they roost  or sleep  together  <end> <pad> <pad>
# <start> phần lớn chúng đậu và ngủ cùng nhau  <end> <pad> <pad>
# <start> nicolas perony  i aposm okay  thanks  <end> <pad> <pad>
# <start> nicolas perony  tôi ổn mà  cảm ơn nhé  <end>
# <start> but is it okay to do these associations  <end> <pad> <pad>
# <start> nhưng liên kết như vậy có ổn không  <end> <pad> <pad>
# <start> he wanted to be a chef really badly  <end> <pad> <pad>
# <start> em ấy luôn ước muốn trở thành đầu bếp  <end> <pad>
# <start> it aposs like going from ox carts to the airplane  <end>
# <start> giống như chuyển từ xe bò sang đi máy bay  <end>
# <start> quot honey  come over for dinner  quot <end> <pad> <pad>
# <start> quot con ơi  ra ăn tối  quot <end> <pad> <pad>
# <start> silence  quot can you listen to me  quot <end> <pad>
# <start> im lặng  quot nghe bố nói không đấy  quot <end>
# <start> and so since then  our life has changed  <end> <pad>
# <start> cuộc sống của chúng tôi đã thay đổi  <end> <pad> <pad>
# <start> lessons are interleaved sequences of videos and interactive exercises  <end> <pad>
# <start> bài học là một chuỗi video và bài tập tương tác <end>
# <start> heck  they can even mute the professor  <end> <pad> <pad>
# <start> hay  thậm chí có thể tắt tiếng  <end> <pad> <pad>
# <start> and this can also be graded by the computer  <end> <pad>
# <start> kết quả sẽ được chấm điểm bằng máy tính  <end> <pad>
# <start> we will have to move from lecture halls to espaces  <end>
# <start> chuyển từ giảng đường tới không gian trực tuyến  <end> <pad>
# <start> i have worked with more than  companies  <end> <pad> <pad>
# <start> tôi đã làm việc với hơn  công ty <end> <pad> <pad>
# <start> the way we organize is based on two pillars  <end> <pad>
# <start> cách chúng ta tổ chức dựa trên hai trụ cột <end> <pad>
# <start> the hard  structure  processes  systems  <end> <pad> <pad>
# <start> phần cứng kết cấu  quy trình  hệ thống <end> <pad>
# <start> so  what was the solution using the hard approach  <end>
# <start> vậy  giải pháp ở đây là gì  <end> <pad> <pad>
# <start> that came on top of  other kpis  <end> <pad> <pad>
# <start> nó đứng hàng thứ  các kpi khác  <end> <pad> <pad>
# <start> the connections  the interactions  the synapses  <end> <pad> <pad>
# <start> các liên kết  tương tác  các liên hợp  <end>
# <start> the hard approach is unable to foster cooperation  <end> <pad> <pad>
# <start> phương pháp cứng không thể củng cố sự hợp tác  <end>
# <start> you can increase the shadow of the future  <end> <pad> <pad>
# <start> bạn có thể gia tăng cái bóng của tương lai  <end>
# <start> and then put it back in your character  <end> <pad> <pad>
# <start> và sau đó truyền lại cho nhân vật của bạn  <end>
# <start> just laying there  eyes glazed over  quot <end> <pad> <pad>
# <start> hắn nằm ở đó  mắt đờ cả ra  quot <end>
# <start> we didn apost have to communicate verbally about this  <end> <pad>
# <start> chúng tôi không hề nói lời nào để phân việc <end> <pad>
# <start> it became very popular in the th century  <end> <pad> <pad>
# <start> nó đã rất phổ biến trong thế kỷ   <end> <pad>
# <start> and it aposs not just fun and games  <end> <pad> <pad>
# <start> và nó không chỉ là trò vui hay trò giải trí <end>
# <start> maybe they should be able to take chances and improvise  <end>
# <start> có thể chúng nên mạo hiểm diễn ngẫu hứng <end> <pad> <pad>
# <start> but i also had noticed that it wasn apost working  <end>
# <start> nhưng tôi cũng nhận thấy việc đó không hiệu quả  <end>
# <start> i met one of them  i was in beijing  <end>
# <start> tôi đã gặp một nhóm  khi tôi ở bắc kinh <end>
# <start> and it aposs part of what tedwomen does  <end> <pad> <pad>
# <start> và đó là một phần mà tedwomen đang làm  <end> <pad>
# <start> if you are a black woman   cents  <end> <pad>
# <start> nếu bạn là phụ nữ da đen   cents  <end>
# <start> i said  quot the menu  please  quot <end> <pad>
# <start> quot vui lòng cho xin thực đơn  quot <end> <pad> <pad>
# <start> it made me mad  it definitely hurts  <end> <pad> <pad>
# <start> nó làm tôi bực lắm  thực sự tủi lòng  <end>
# <start> you wouldn apost believe it aposs a local product  <end> <pad>
# <start> bạn sẽ không tin nó là hàng trong nước  <end> <pad>
# <start> regardless of the who  how and why  <end> <pad> <pad>
# <start> mặc kệ ai  thế nào hay tại sao  <end> <pad>
# <start> i asked her once how things were going  <end> <pad> <pad>
# <start> hôm nọ  tôi hỏi cô ấy sống ra sao  <end>
# <start> that aposs the first thing we can do  <end> <pad> <pad>
# <start> đó là điều đầu tiên ta có thể làm  <end> <pad>
# <start> and i aposm thinking  what are they imagining  <end> <pad>
# <start> tôi thầm nghĩ  quot họ nghĩ sao vậy  quot <end>
# <start> the epic journey is going to be over  <end> <pad> <pad>
# <start> chuyến hành trình vang dội sẽ chấm dứt  <end> <pad> <pad>
# <start> that little tracker that was on the computer  <end> <pad> <pad>
# <start> cái chấm nhỏ theo dõi trên máy tính  <end> <pad> <pad>
# <start> and yeah  i stand before you now  <end> <pad> <pad>
# <start> vâng  tôi đứng trước bạn lúc này  <end> <pad> <pad>
# <start> i aposve signed a wonderful major book contract  <end> <pad> <pad>
# <start> đã kí một hợp đồng xuất bản sách tuyệt vời  <end>
# <start> and so this talk is going to be for him  <end>
# <start> vâng  bài nói này là dành tặng riêng ông  <end>
# <start> solly grew up tending to his father aposs cattle  <end> <pad>
# <start> solly lớn lên cùng với việc chăm sóc gia súc  <end>
# <start> wham  it hits me by my right leg  <end> <pad>
# <start> trời ơi  nó cắn chân phải của tôi  <end> <pad>
# <start> it goes to bite me a second time  <end> <pad> <pad>
# <start> nó sắp sửa ngoạm lấy tôi lần thứ hai  <end> <pad>
# <start> he picks me and puts me on his shoulder  <end> <pad>
# <start> anh ấy nhấc tôi lên và vác tôi trên vai <end> <pad>
# <start> it was sort of a hollow in the ground  <end> <pad>
# <start> gần giống như một cái hố trên đất  <end> <pad> <pad>
# <start> the rest of the herd turned and began to follow  <end>
# <start> những con khác trong đàn bắt đầu đi theo  <end> <pad>
# <start> that is the system that seems to work  quot <end> <pad>
# <start> đó là một hệ thống có hiệu quả  quot <end> <pad>
# <start> it aposs the model that put food on the table  <end>
# <start> đó là mô hình đặt thức ăn lên bàn <end> <pad> <pad>
# <start> this is an affidavit from the zambian government  <end> <pad> <pad>
# <start> đây là một bản tuyên thệ từ chính phủ zambia  <end>
# <start> abha dawesar  life in the quot digital now quot <end> <pad>
# <start> abha dawesar  cuộc sống trong quot hiện tại số quot <end>
# <start> discrete moments from our lives are its chapters  <end> <pad> <pad>
# <start> những khoảnh khắc riêng là những chương của tác phẩm  <end>
# <start> but the story is not about these chapters  <end> <pad> <pad>
# <start> nhưng câu chuyện sẽ không chỉ gồm các chương <end> <pad> <pad>
# <start> are you reading an interview by an author  <end> <pad> <pad>
# <start> bạn đang đọc bài phỏng vấn của một tác giả  <end>
# <start> but we don apost need to let it  <end> <pad> <pad>
# <start> nhưng chúng ta không để cho nó làm như vậy  <end>
# <start> that aposs where all the resources come from  <end> <pad> <pad>
# <start> đó là nơi sản sinh các nguồn tài trợ  <end> <pad>
# <start> we talk about what we don apost know  <end> <pad> <pad>
# <start> mà chỉ nói về những gì mình không biết  <end> <pad>
# <start> this is the stuff that aposs exhilarating and interesting  <end> <pad>
# <start> đó là cái thú vị và hào hứng  <end> <pad> <pad>
# <start> it is  if you will  the ignorance  <end> <pad>
# <start> đó là về apos sự thiếu hiểu biết apos  <end> <pad>
# <start> what are we using this collection of facts for  <end> <pad>
# <start> dùng một mớ kiến thức này để làm gì  <end> <pad>
# <start> but nonetheless  it aposs what the argument is about  <end>
# <start> nhưng tóm lại  đấy là nội dung tranh luận  <end>
# <start> because it aposs not always quite so straightforward  <end> <pad> <pad>
# <start> vì không phải lúc nào cũng thẳng vào vấn đề  <end>
# <start> what aposs the process by which that could happen  <end> <pad>
# <start> quá trình này diễn ra như thế nào  <end> <pad> <pad>
# <start> this can apost possibly continue to go on  <end> <pad> <pad>
# <start> tình trạng này có thể còn tiếp diễn  <end> <pad> <pad>
# <start> it shouldn apost take minutes or hours to work  <end> <pad>
# <start> chứ không phải đợi đến vài phút hay vài giờ  <end>
# <start> sr  so what do you think  xu  <end> <pad>
# <start> sr  vậy bạn nghĩ sao  xu  <end> <pad> <pad>
# <start> xl  yep  you heard it right  <end> <pad> <pad>
# <start> xl  đúng  bạn không nghe nhầm đâu  <end> <pad>
# <start> xl  and this is what we saw  <end> <pad> <pad>
# <start> xl  và đây là những gì chúng tôi thấy  <end>
# <start> sr  quot did that just work  quot <end> <pad> <pad>
# <start> sr  quot nó đã hiệu quả phải không  quot <end>
# <start> maybe we can take a look at some of those  <end>
# <start> chúng ta có thể xem một vài ý kiến  <end> <pad>
# <start> it aposs sort of like making a remix tape  <end> <pad>
# <start> nó giống như tạo một đoạn nhạc được hoà lại  <end>
# <start> sr  so how do we do this  <end> <pad> <pad>
# <start> sr  vậy làm thế nào để làm được  <end> <pad>
# <start> she ate too much  she got unlucky  <end> <pad> <pad>
# <start> cô ta ăn nhiều quá  thật không may  <end> <pad>
# <start> this is called fuel partitioning in the lingo  <end> <pad> <pad>
# <start> tiếng lóng gọi là ngăn cách nhiên liệu  <end> <pad> <pad>
# <start> some think it aposs too many calories consumed  <end> <pad> <pad>
# <start> một số cho rằng vì việc tiêu thụ quá nhiều calo <end>
# <start> sometimes i think back to that night in the er <end> <pad>
# <start> đôi khi tôi nghĩ về đêm tại phòng cấp cứu  <end>
# <start> i aposd like to tell her how sorry i am  <end>
# <start> để cho cô ấy biết tôi ân hận như thế nào <end>
# <start> the idea of eliminating poverty is a great goal  <end> <pad>
# <start> mong muốn xoá nghèo là  mục tiêu vĩ đại  <end>
# <start> why  because you aposre all too old  <end> <pad> <pad>
# <start> tại sao nhỉ  vì bạn quá lớn tuổi rồi  <end>
# <start> simply not done  the house doesn apost work  <end> <pad>
# <start> nhưng không làm  rồi nhà không dùng được  <end> <pad>
# <start> they don apost work  we have to fix them  <end>
# <start> chúng không dùng được  chúng tôi phải sửa lại  <end>
# <start> and we aposll go a lot further than that  <end> <pad>
# <start> và chúng tôi đi xa hơn thế nhiều  <end> <pad> <pad>
# <start> why  because that flushes the bug out  <end> <pad> <pad>
# <start> tại sao  vì nước rửa được côn trùng  <end> <pad>
# <start> he was loaned to us by a mining company  <end> <pad>
# <start> một công ty khai khoáng cho chúng tôi mượn  <end> <pad>
# <start> then we wanted to get rid of the bug generally  <end>
# <start> rồi chúng tôi muốn đuổi hết đám bọ đi  <end> <pad>
# <start> and finally  you get a good eye  <end> <pad> <pad>
# <start> và cuối cùng  ta có đôi mắt đẹp  <end> <pad>
# <start> so all of a sudden we had two problems  <end> <pad>
# <start> vậy là bất thần chúng tôi có  vấn đề  <end>
# <start> i put it to you  is this eliminating poverty  <end>
# <start> về phía bạn  điều này có xoá nghèo không  <end>
# <start> and that  to me  is the key  <end> <pad>
# <start> với tôi  điều đó là cốt lõi  <end> <pad> <pad>

# %%
x_train, x_val, y_train, y_val = train_test_split(inp_tensor, tar_tensor, test_size=0.1)

BATCH_SIZE = 32
BUFFER_SIZE = x_train.shape[0]
N_BATCH = BUFFER_SIZE//BATCH_SIZE
hidden_unit = 1024
embedding_size = 256
print(BUFFER_SIZE)


dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
dataset = dataset.batch(BATCH_SIZE)
# Out:
# 5414

# %%
tmp_x, tmp_y = next(iter(dataset))
print(tmp_x.shape)
print(tmp_y.shape)
# Out:
# (32, 13)
# (32, 13)

# %%
class Encode(tf.keras.Model):
    def __init__(self, embedding_size, vocab_size, hidden_units):
        super(Encode, self).__init__()
        self.Embedding = tf.keras.layers.Embedding(vocab_size,embedding_size)
        self.GRU = tf.keras.layers.GRU(
            hidden_units,
            return_sequences=True,
            return_state=True,
            recurrent_initializer='glorot_uniform')
        self.hidden_units = hidden_units
        
    def call(self, x, hidden_state):
        try:
            x = self.Embedding(x)
        except:
            print(x, print(inp_lang.vocab_size))          
        outputs, last_state = self.GRU(x, hidden_state)
        return outputs, last_state
    
    def init_hidden_state(self, batch_size):
        return tf.zeros([batch_size, self.hidden_units])

# %%
encoder = Encode(embedding_size, inp_lang.vocab_size, hidden_unit)
hidden_state = encoder.init_hidden_state(BATCH_SIZE)
tmp_outputs, last_state = encoder(tmp_x, hidden_state)
print(tmp_outputs.shape)
print(last_state.shape)
# Out:
# (32, 13, 1024)
# (32, 1024)

# %%
class Attention(tf.keras.Model):
    def __init__(self, hidden_units):
        super(Attention, self).__init__()
        self.W_out_encode = tf.keras.layers.Dense(hidden_unit)
        self.W_state = tf.keras.layers.Dense(hidden_unit)
        self.V = tf.keras.layers.Dense(1)
        
    def call(self, encode_outs, pre_state):
        pre_state = tf.expand_dims(pre_state, axis=1)
        pre_state = self.W_state(pre_state)
        encode_outs = self.W_out_encode(encode_outs)
        score = self.V(
            tf.nn.tanh(
                pre_state + encode_outs)
        )
        score = tf.nn.softmax(score, axis=1)
        context_vector = score*encode_outs
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, score

# %%
attention = Attention(hidden_unit)
context_vector, attention_weight = attention(tmp_outputs, last_state)
print(context_vector.shape, attention_weight.shape)
# Out:
# (32, 1024) (32, 13, 1)

# %%
from tensorflow.python.keras.layers import recurrent
class Decode(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, hidden_units):
        super(Decode, self).__init__()
        self.hidden_units = hidden_units
        self.Embedding = tf.keras.layers.Embedding(vocab_size,embedding_size)
        self.Attention = Attention(hidden_units)
        self.GRU = tf.keras.layers.GRU(
            hidden_units,
            return_sequences=True,
            return_state=True,
            recurrent_initializer='glorot_uniform'
        )
        self.Fc = tf.keras.layers.Dense(vocab_size)
            
    def call(self, x, encode_outs, pre_state):
        x = tf.expand_dims(x, axis=1)
        try:
            x = self.Embedding(x)
        except:
            print(x, print(tar_lang.vocab_size))          
        context_vector, attention_weight = self.Attention(encode_outs, pre_state)
        context_vector = tf.expand_dims(context_vector, axis=1)
        gru_inp = tf.concat([x, context_vector], axis=-1)
        out_gru, state = self.GRU(gru_inp)
        out_gru = tf.reshape(out_gru, (-1, out_gru.shape[2]))
        return self.Fc(out_gru), state
    
    
decode = Decode(tar_lang.vocab_size, embedding_size, hidden_unit)
print(last_state.shape, tmp_outputs.shape, tmp_y[:, 0].shape)
decode_out, state = decode(tmp_y[:, 0], tmp_outputs, last_state)
# Out:
# (32, 1024) (32, 13, 1024) (32,)

# %%
def loss_function(real, pred):
    mask = 1 - np.equal(real, 0)
    loss_ = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=real, logits=pred) * mask
    return tf.reduce_mean(loss_)

# %%
EPOCHS = 10
# optimizer = tf.train.AdamOptimizer()
optimizer = tf.optimizers.Adam()
encoder = Encode(embedding_size, vocab_size=inp_lang.vocab_size, hidden_units=hidden_unit)
decoder = Decode(vocab_size=tar_lang.vocab_size, embedding_size=embedding_size, hidden_units=hidden_unit)

# %%
for epoch in range(EPOCHS):
    total_loss = 0
    for batch_id, (x, y) in enumerate(dataset.take(N_BATCH)):
        loss = 0
        with tf.GradientTape() as tape:
            first_state = encoder.init_hidden_state(batch_size=BATCH_SIZE)
            encode_outs, last_state = encoder(x, first_state)
            decode_state = last_state
            decode_input = [tar_lang.word2id["<start>"]]*BATCH_SIZE
            
            for i in range(1, y.shape[1]):
                decode_out, decode_state = decoder(decode_input, encode_outs, decode_state)
                loss += loss_function(y[:, i], decode_out)
                decode_input = y[:, i]
                
            train_vars = encoder.trainable_variables + decoder.trainable_variables
            grads = tape.gradient(loss, train_vars)
            optimizer.apply_gradients(zip(grads, train_vars))
        total_loss += loss
    print(total_loss.numpy())
# Out:
# 10623.204
# 9063.127
# 8131.009
# 7305.0083
# 6525.9995
# 5809.744
# 5131.504
# 4571.126
# 3989.8508
# 3586.5583

# %%
# 10592.284
# 9064.408
# 8132.6377
# 7290.939
# 6500.7266
# 5782.4717
# 5174.547
# 4558.6675
# 3989.8186

# %%
def translate(inputs):
    print(inp_lang.vector_to_sentence(inputs[0].numpy()))
    result = ''

    hidden = encoder.init_hidden_state(batch_size=1)
    enc_out, enc_hidden = encoder(inputs, hidden)
    dec_hidden = enc_hidden
    print(enc_out.shape, dec_hidden.shape)
    
    dec_input = [tar_lang.word2id['<start>']]
    for t in range(tar_lang.max_len):
        predictions, dec_hidden = decoder(dec_input, enc_out, dec_hidden)
        predicted_id = tf.argmax(predictions[0]).numpy()
        result += tar_lang.id2word[predicted_id] + ' '
        dec_input = [predicted_id]
    return result
  
for inp, tar in dataset.take(N_BATCH):
    print(translate(inp[1:2,:]))
    break
# Out:
# <start> the idea of eliminating poverty is a great goal  <end> <pad>
# (1, 13, 1024) (1, 1024)
# ý tưởng xoá nghèo  <end>  <end>  <end>  <end>
